# %%
# install / upgrade necessary packages
# !pip install easydict
# !pip install numpy
# !pip install numpy --upgrade # upgrade numpy to at least 1.16
# !pip install torch --upgrade # upgrade pytorch to 1.5.1

# %%
import os
from easydict import EasyDict
from utils import *
import matplotlib.pyplot as plt
import torch
import numpy as np
import random
# set experiment configs
opt = EasyDict()
# choose a dataset from ["quarter-circle", "half-circle"]
opt.data = "quarter-circle"
# choose a model from ["CIDA", "PCIDA", "ADDA", "SO", "DANN", "CDANN", "MDD", "CUA"]
opt.model = "DANN"
# choose run on which device ["cuda", "cpu"]
opt.device = "cuda"

# set random seed
opt.seed = 2333

print("Numpy version:", np.__version__)
print("pytorch version:", torch.__version__)
# Out:
# Numpy version: 1.19.2
# pytorch version: 1.9.1+cu102

# %%
# training configs
opt.num_epoch = 800
opt.batch_size = 10
opt.lr = 1e-4
opt.lr_T = 1e-4
opt.gamma = 100
opt.beta1 = 0.9
opt.weight_decay = 5e-4
opt.wgan = False
opt.no_bn = True  # do not use batch normalization # True

# model size configs
opt.nx = 2  # dimension of the input data
opt.nh = 800  # dimension of hidden
opt.nc = 2  # number of label class

# dataset configs

opt.dim_domain = 1  # dimension of domain index

# number of domains in the dataset
if opt.data == "quarter-circle":
    opt.num_domain = 15
    opt.num_source = 6
    opt.normalize_domain = False
elif opt.data == "half-circle":
    opt.num_domain = 30
    opt.num_source = 6
    opt.normalize_domain = False    
elif opt.data == "sine":
    opt.num_domain = 12
    opt.num_source = 5
    opt.normalize_domain = True  # normalize data per domain
else:
    assert False, "Can't find data"
opt.num_target = opt.num_domain - opt.num_source

# model specific configs

opt.cond_disc = False  # use conditional discriminator
opt.continual_da = False  # use continual domain adaptation

opt.lambda_gan = 2.0

if opt.model == 'CIDA':
    opt.lambda_gan = 0.4

elif opt.model == 'PCIDA':
    opt.lambda_gan = 1.0
    opt.nmix = 1  # number of mix guassian for the discriminator prediction
    # opt.no_bn = False

elif opt.model == "MDD":
    opt.lambda_src = 1.0
    opt.lambda_tgt = 1.0
    opt.lambda_gan = 2.0
    opt.num_epoch = 160  # early stop (optional) 

elif opt.model == 'CDANN':
    opt.cond_disc = True

elif opt.model == 'CUA':
    opt.continual_da = True
    opt.num_da_step = 5  # number of steps of domain adaptation
    opt.num_epoch_pre = 10  # number of epochs of pretraining in source domain
    opt.num_epoch_sub = 50  # number of epochs of adapting to a new sub target domain
    opt.lr_decay_period = 500
    opt.lambda_gan = 1.0
    opt.lambda_rpy = 0.3

opt.exp = opt.data + '_' + opt.model
opt.outf = './dump/' + opt.exp
os.system('mkdir -p ' + opt.outf)

opt.use_resample = False

# %%
from dataset import *
from plot import plot_dataset

# load raw data
data_pkl = read_pickle(f'./data/{opt.data}.pkl')
print(f"Data: {data_pkl['data'].shape}\nLabel: {data_pkl['label'].shape}")
# visualize raw data
plot_dataset(data_pkl)

# build dataset
data = data_pkl['data']
data_mean = data.mean(0, keepdims=True)
data_std = data.std(0, keepdims=True)
data_pkl['data'] = (data - data_mean) / data_std  # normalize the raw data
datasets = [ToyDataset(data_pkl, i, opt) for i in range(opt.num_domain)]  # sub dataset for each domain
dataset = SeqToyDataset(datasets, size=len(datasets[0]))  # mix sub dataset to a large one
dataloader = DataLoader(
    dataset=dataset,
    shuffle=True,
    batch_size=opt.batch_size
)
# Out:
# Data: (3000, 2)
# Label: (3000,)
# SeqDataset Size 100 Sub Size [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100]

# %%
# %load_ext autoreload
# %autoreload 2
from model import get_model

# set random seed (for reproducibility)
np.random.seed(opt.seed)
random.seed(opt.seed)
torch.manual_seed(opt.seed)

# build the model
modelClass = get_model(opt.model)
model = modelClass(opt)
model.to(opt.device)
print(model)

if opt.normalize_domain:
    model.set_data_stats(
        dm=[d.data_m for d in datasets],
        ds=[d.data_s for d in datasets],
    )
    
# train the model
if not opt.continual_da:
    # one-step adaptation
    for epoch in range(opt.num_epoch):
        model.learn(epoch, dataloader)
        if (epoch + 1) % 100 == 0 or (epoch + 1) == opt.num_epoch:
            model.save()
            # model.visualize_D()
            # model.visualize_F()
            # model.visualize_E()
        if (epoch + 1) % 50 == 0:    
            model.test(epoch, dataloader)
else:
    # pretrain on source
    print('===> pretrain the classifer')
    model.prepare_trainer(init=True)
    for epoch in range(opt.num_epoch_pre):
        model.learn(epoch, dataloader, init=True)
        if (epoch + 1) % 10 == 0:
            model.save()
            model.visualize_F()
            model.test(epoch, dataloader)
    # step-by-step domain adapt
    ds_size = len(datasets[0])
    replay_datasets = [datasets[i] for i in range(opt.num_source)]
    print('===> start continual DA')
    model.prepare_trainer(init=False)
    for phase in range(opt.num_source, opt.num_domain):
        continual_dataset = SeqToyDataset(replay_datasets, size=ds_size)
        continual_dataloader = DataLoader(
            dataset=continual_dataset,
            shuffle=True,
            batch_size=opt.batch_size,
            num_workers=4,
        )
        model.set_phase(phase)
        for epoch in range(opt.num_epoch_sub):
            model.learn(epoch, (dataloader, continual_dataloader), init=False)
        # model.visualize_F(phase)
        model.save()
        model.test(epoch, dataloader)
        replay_data, replay_label = model.gen_replay_dataset(dataloader)
        replay_datasets.append(ReplayDataset(replay_data, replay_label, opt))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ===> Unconditioned Discriminator
# ===> Discriminator will distinguish 15 domains
# DANN(
#   (netE): FeatureNet(
#     (fc1): Linear(in_features=2, out_features=800, bias=True)
#     (fc2): Linear(in_features=1600, out_features=1600, bias=True)
#     (fc3): Linear(in_features=1600, out_features=1600, bias=True)
#     (fc4): Linear(in_features=1600, out_features=1600, bias=True)
#     (fc_final): Linear(in_features=1600, out_features=800, bias=True)
#     (fc1_var): Linear(in_features=1, out_features=800, bias=True)
#     (fc2_var): Linear(in_features=800, out_features=800, bias=True)
#   )
#   (netF): PredNet(
#     (fc3): Linear(in_features=800, out_features=800, bias=True)
#     (bn3): Identity()
#     (fc4): Linear(in_features=800, out_features=800, bias=True)
#     (bn4): Identity()
#     (fc_final): Linear(in_features=800, out_features=2, bias=True)
#   )
#   (netD): ClassDiscNet(
#     (fc3): Linear(in_features=800, out_features=800, bias=True)
#     (bn3): Identity()
#     (fc4): Linear(in_features=800, out_features=800, bias=True)
#     (bn4): Identity()
#     (fc5): Linear(in_features=800, out_features=800, bias=True)
#     (bn5): Identity()
#     (fc6): Linear(in_features=800, out_features=800, bias=True)
#     (bn6): Identity()
#     (fc7): Linear(in_features=800, out_features=800, bias=True)
#     (bn7): Identity()
#     (fc_final): Linear(in_features=800, out_features=15, bias=True)
#   )
# )
# [Train][9] Loss: D 2.709 E_gan -2.706 E_pred 0.167
# [Train][9] Accuracy: total average 74.5, in each domain [85. 90. 91. 95. 93. 96. 92. 92. 76. 66. 55. 47. 44. 49. 47.]
# [Train][19] Loss: D 2.705 E_gan -2.703 E_pred 0.103
# [Train][19] Accuracy: total average 91.6, in each domain [95. 91. 96. 96. 97. 97. 93. 92. 95. 91. 96. 90. 84. 82. 79.]
# [Train][29] Loss: D 2.700 E_gan -2.699 E_pred 0.068
# [Train][29] Accuracy: total average 91.6, in each domain [95. 96. 96. 99. 98. 98. 93. 90. 91. 93. 95. 92. 85. 79. 74.]
# [Train][39] Loss: D 2.701 E_gan -2.700 E_pred 0.042
# [Train][39] Accuracy: total average 96.3, in each domain [ 97.  97.  98. 100.  98. 100. 100. 100. 100.  94.  96.  97.  94.  89.
#   84.]
# [Train][49] Loss: D 2.708 E_gan -2.707 E_pred 0.051
# [Train][49] Accuracy: total average 94.3, in each domain [ 96.  98.  96.  98.  99. 100.  99.  99.  95.  99.  98.  94.  85.  82.
#   77.]
# [Test][49] Accuracy: total average 97.2, in each domain [100. 100.  98. 100. 100. 100. 100. 100.  96.  98. 100.  98.  93.  87.
#   88.]
# [Train][59] Loss: D 2.695 E_gan -2.693 E_pred 0.035
# [Train][59] Accuracy: total average 91.3, in each domain [ 97.  94. 100. 100.  99. 100.  98.  98.  96.  94.  95.  89.  75.  70.
#   65.]
# [Train][69] Loss: D 2.705 E_gan -2.704 E_pred 0.170
# [Train][69] Accuracy: total average 94.9, in each domain [93. 91. 93. 94. 95. 97. 97. 95. 96. 93. 95. 94. 97. 97. 96.]
# [Train][79] Loss: D 2.694 E_gan -2.692 E_pred 0.026
# [Train][79] Accuracy: total average 96.9, in each domain [ 99.  98.  98. 100.  99. 100. 100.  98.  96.  93.  95.  96.  94.  93.
#   95.]
# [Train][89] Loss: D 2.703 E_gan -2.702 E_pred 0.040
# [Train][89] Accuracy: total average 95.2, in each domain [98. 99. 96. 99. 98. 99. 99. 98. 96. 91. 92. 94. 92. 87. 90.]
# [Train][99] Loss: D 2.709 E_gan -2.709 E_pred 0.025
# [Train][99] Accuracy: total average 92.9, in each domain [100.  97.  98. 100. 100. 100. 100.  97.  93.  87.  86.  89.  84.  81.
#   82.]
# [Test][99] Accuracy: total average 92.5, in each domain [100. 100.  98.  99. 100. 100. 100.  97.  92.  87.  86.  88.  79.  80.
#   82.]
# [Train][109] Loss: D 2.694 E_gan -2.693 E_pred 0.021
# [Train][109] Accuracy: total average 91.6, in each domain [100. 100.  98. 100.  98. 100.  98.  98.  96.  94.  93.  84.  73.  71.
#   71.]
# [Train][119] Loss: D 2.704 E_gan -2.703 E_pred 0.026
# [Train][119] Accuracy: total average 97.1, in each domain [ 98.  98.  97.  99.  99. 100.  99.  97.  98.  99.  98.  97.  90.  90.
#   97.]
# [Train][129] Loss: D 2.706 E_gan -2.706 E_pred 0.045
# [Train][129] Accuracy: total average 97.7, in each domain [ 99.  95.  97.  98.  98. 100.  98.  99.  98.  99.  98.  98.  96.  95.
#   97.]
# [Train][139] Loss: D 2.702 E_gan -2.702 E_pred 0.018
# [Train][139] Accuracy: total average 95.3, in each domain [ 98. 100.  99. 100.  99. 100. 100.  99.  96.  87.  91.  93.  91.  87.
#   89.]
# [Train][149] Loss: D 2.713 E_gan -2.712 E_pred 0.014
# [Train][149] Accuracy: total average 96.8, in each domain [100.  99.  99. 100. 100. 100. 100.  98.  95.  88.  93.  94.  96.  96.
#   94.]
# [Test][149] Accuracy: total average 95.1, in each domain [100.  99. 100. 100.  99. 100. 100.  97.  93.  87.  90.  93.  92.  87.
#   89.]
# [Train][159] Loss: D 2.703 E_gan -2.703 E_pred 0.061
# [Train][159] Accuracy: total average 96.3, in each domain [ 97.  95.  95. 100.  98. 100.  97.  98.  95.  99. 100.  96.  89.  90.
#   96.]
# [Train][169] Loss: D 2.706 E_gan -2.706 E_pred 0.011
# [Train][169] Accuracy: total average 97.3, in each domain [100.  99.  99. 100. 100. 100. 100.  98.  95.  89.  98.  97.  93.  94.
#   98.]
# [Train][179] Loss: D 2.709 E_gan -2.708 E_pred 0.010
# [Train][179] Accuracy: total average 95.1, in each domain [100.  98. 100. 100. 100. 100.  99.  98.  98.  98.  96.  92.  79.  82.
#   86.]
# [Train][189] Loss: D 2.707 E_gan -2.706 E_pred 0.110
# [Train][189] Accuracy: total average 95.9, in each domain [93. 96. 98. 98. 98. 96. 99. 98. 94. 93. 95. 95. 97. 98. 90.]
# [Train][199] Loss: D 2.705 E_gan -2.704 E_pred 0.014
# [Train][199] Accuracy: total average 98.0, in each domain [100.  99.  98. 100. 100. 100. 100.  99.  95.  98.  99.  98.  91.  95.
#   98.]
# [Test][199] Accuracy: total average 98.1, in each domain [100. 100.  99. 100. 100. 100.  99.  99.  95.  98.  99.  98.  91.  95.
#   98.]
# [Train][209] Loss: D 2.707 E_gan -2.707 E_pred 0.016
# [Train][209] Accuracy: total average 96.2, in each domain [ 99.  99. 100. 100.  99. 100. 100.  98.  95.  87.  91.  93.  97.  95.
#   90.]
# [Train][219] Loss: D 2.703 E_gan -2.703 E_pred 0.010
# [Train][219] Accuracy: total average 98.3, in each domain [ 99. 100. 100. 100. 100. 100. 100.  99.  95.  95.  99.  97.  95.  96.
#   99.]
# [Train][229] Loss: D 2.700 E_gan -2.700 E_pred 0.007
# [Train][229] Accuracy: total average 96.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  97.  98.  98.  94.  89.  86.
#   94.]
# [Train][239] Loss: D 2.704 E_gan -2.704 E_pred 0.036
# [Train][239] Accuracy: total average 95.7, in each domain [ 99.  96.  98. 100.  98. 100. 100.  99.  94.  88.  92.  93.  97.  93.
#   89.]
# [Train][249] Loss: D 2.704 E_gan -2.704 E_pred 0.009
# [Train][249] Accuracy: total average 94.3, in each domain [ 99.  99.  99. 100. 100. 100. 100.  99.  95.  98.  98.  92.  75.  79.
#   82.]
# [Test][249] Accuracy: total average 94.3, in each domain [100. 100. 100. 100. 100. 100.  99.  99.  95.  98.  98.  92.  75.  78.
#   81.]
# [Train][259] Loss: D 2.703 E_gan -2.703 E_pred 0.015
# [Train][259] Accuracy: total average 96.9, in each domain [100.  98. 100. 100.  99.  99. 100.  98.  93.  88.  93.  94.  99.  96.
#   96.]
# [Train][269] Loss: D 2.706 E_gan -2.706 E_pred 0.006
# [Train][269] Accuracy: total average 98.0, in each domain [100.  99. 100. 100. 100. 100. 100.  99.  95.  98.  99.  97.  90.  95.
#   98.]
# [Train][279] Loss: D 2.706 E_gan -2.706 E_pred 0.012
# [Train][279] Accuracy: total average 97.4, in each domain [100.  99.  99. 100. 100. 100. 100.  99.  96.  90.  96.  94.  99.  96.
#   93.]
# [Train][289] Loss: D 2.706 E_gan -2.706 E_pred 0.010
# [Train][289] Accuracy: total average 97.5, in each domain [ 99.  99. 100. 100. 100. 100.  99.  98.  95.  99.  99.  96.  90.  92.
#   97.]
# [Train][299] Loss: D 2.702 E_gan -2.702 E_pred 0.031
# [Train][299] Accuracy: total average 95.9, in each domain [ 99.  97.  98.  98.  98. 100. 100.  98.  96.  98.  98.  95.  83.  85.
#   95.]
# [Test][299] Accuracy: total average 96.3, in each domain [ 97.  95.  98.  99.  99. 100.  99.  98.  97.  98.  98.  96.  88.  87.
#   95.]
# [Train][309] Loss: D 2.705 E_gan -2.705 E_pred 0.009
# [Train][309] Accuracy: total average 95.1, in each domain [ 99.  99.  98. 100. 100. 100. 100.  97.  93.  87.  90.  93.  92.  90.
#   88.]
# [Train][319] Loss: D 2.707 E_gan -2.706 E_pred 0.007
# [Train][319] Accuracy: total average 98.1, in each domain [100.  99. 100. 100. 100. 100. 100.  99.  95.  93.  99.  97.  94.  98.
#   98.]
# [Train][329] Loss: D 2.705 E_gan -2.705 E_pred 0.021
# [Train][329] Accuracy: total average 97.4, in each domain [ 98. 100.  98. 100.  99. 100.  99.  99.  95.  96.  99.  95.  90.  95.
#   98.]
# [Train][339] Loss: D 2.705 E_gan -2.705 E_pred 0.019
# [Train][339] Accuracy: total average 97.2, in each domain [100.  97.  99. 100.  98. 100. 100. 100.  95.  89.  95.  95.  98.  98.
#   94.]
# [Train][349] Loss: D 2.705 E_gan -2.705 E_pred 0.004
# [Train][349] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100. 100.  99.  95.  94.  99.  97.  91.  96.
#   98.]
# [Test][349] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100. 100.  99.  95.  94.  99.  97.  91.  95.
#   99.]
# [Train][359] Loss: D 2.705 E_gan -2.705 E_pred 0.005
# [Train][359] Accuracy: total average 97.9, in each domain [100. 100.  99. 100. 100. 100. 100.  98.  95.  98.  99.  98.  90.  95.
#   97.]
# [Train][369] Loss: D 2.705 E_gan -2.705 E_pred 0.007
# [Train][369] Accuracy: total average 97.7, in each domain [ 99.  99. 100. 100. 100. 100. 100.  99.  95.  90.  96.  96.  96.  98.
#   97.]
# [Train][379] Loss: D 2.705 E_gan -2.705 E_pred 0.005
# [Train][379] Accuracy: total average 96.7, in each domain [100.  99. 100. 100. 100. 100. 100.  97.  95.  88.  93.  93.  98.  96.
#   91.]
# [Train][389] Loss: D 2.705 E_gan -2.705 E_pred 0.007
# [Train][389] Accuracy: total average 97.1, in each domain [ 99.  99. 100. 100.  99. 100. 100.  98.  95.  88.  94.  93.  97.  97.
#   98.]
# [Train][399] Loss: D 2.705 E_gan -2.705 E_pred 0.003
# [Train][399] Accuracy: total average 97.7, in each domain [100. 100. 100. 100. 100. 100. 100.  99.  95.  95.  99.  97.  89.  95.
#   97.]
# [Test][399] Accuracy: total average 97.7, in each domain [100. 100. 100. 100. 100. 100. 100.  99.  95.  95.  99.  97.  89.  95.
#   97.]
# [Train][409] Loss: D 2.705 E_gan -2.705 E_pred 0.002
# [Train][409] Accuracy: total average 97.8, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  97.  99.  97.  90.  95.
#   97.]
# [Train][419] Loss: D 2.705 E_gan -2.705 E_pred 0.002
# [Train][419] Accuracy: total average 98.0, in each domain [100. 100. 100. 100. 100. 100. 100.  99.  95.  92.  99.  97.  93.  97.
#   98.]
# [Train][429] Loss: D 2.705 E_gan -2.705 E_pred 0.002
# [Train][429] Accuracy: total average 97.2, in each domain [100. 100. 100. 100. 100. 100. 100.  99.  94.  88.  93.  94.  99.  98.
#   93.]
# [Train][439] Loss: D 2.705 E_gan -2.705 E_pred 0.003
# [Train][439] Accuracy: total average 97.5, in each domain [100. 100. 100. 100. 100. 100. 100.  99.  95.  88.  95.  93.  98.  97.
#   98.]
# [Train][449] Loss: D 2.705 E_gan -2.705 E_pred 0.010
# [Train][449] Accuracy: total average 97.7, in each domain [ 98.  99.  99. 100. 100. 100.  99.  99.  95.  92.  97.  96.  95.  98.
#   98.]
# [Test][449] Accuracy: total average 97.9, in each domain [100.  99. 100. 100. 100. 100. 100.  99.  95.  90.  97.  95.  97.  98.
#   98.]
# [Train][459] Loss: D 2.705 E_gan -2.705 E_pred 0.002
# [Train][459] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100. 100.  98.  95.  92.  97.  96.  94.  98.
#   98.]
# [Train][469] Loss: D 2.705 E_gan -2.705 E_pred 0.002
# [Train][469] Accuracy: total average 98.0, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  93.  97.  96.  95.  98.
#   99.]
# [Train][479] Loss: D 2.705 E_gan -2.705 E_pred 0.001
# [Train][479] Accuracy: total average 98.0, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  93.  97.  96.  95.  98.
#   99.]
# [Train][489] Loss: D 2.705 E_gan -2.705 E_pred 0.002
# [Train][489] Accuracy: total average 98.0, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  93.  97.  96.  95.  98.
#   99.]
# [Train][499] Loss: D 2.705 E_gan -2.705 E_pred 0.001
# [Train][499] Accuracy: total average 98.0, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  93.  97.  96.  95.  98.
#   99.]
# [Test][499] Accuracy: total average 98.0, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  93.  97.  96.  95.  98.
#   99.]
# [Train][509] Loss: D 2.705 E_gan -2.705 E_pred 0.001
# [Train][509] Accuracy: total average 98.1, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  93.  97.  96.  96.  98.
#   99.]
# [Train][519] Loss: D 2.705 E_gan -2.705 E_pred 0.002
# [Train][519] Accuracy: total average 98.1, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  93.  97.  96.  96.  98.
#   99.]
# [Train][529] Loss: D 2.705 E_gan -2.705 E_pred 0.001
# [Train][529] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  96.  96.  98.
#   99.]
# [Train][539] Loss: D 2.705 E_gan -2.705 E_pred 0.001
# [Train][539] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  96.  98.
#   99.]
# [Train][549] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][549] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Test][549] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][559] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][559] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][569] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][569] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][579] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][579] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  94.  97.  98.
#   99.]
# [Train][589] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][589] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  94.  97.  98.
#   99.]
# [Train][599] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][599] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  94.  97.  98.
#   99.]
# [Test][599] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][609] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][609] Accuracy: total average 97.8, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  96.  94.  97.  98.
#   99.]
# [Train][619] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][619] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  94.  97.  98.
#   99.]
# [Train][629] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][629] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  94.  97.  98.
#   99.]
# [Train][639] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][639] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][649] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][649] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Test][649] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][659] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][659] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][669] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][669] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][679] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][679] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][689] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][689] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][699] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][699] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Test][699] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][709] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][709] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  97.  95.  97.  98.
#   99.]
# [Train][719] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][719] Accuracy: total average 97.9, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  96.  95.  97.  98.
#   99.]
# [Train][729] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][729] Accuracy: total average 97.8, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  96.  94.  97.  98.
#   99.]
# [Train][739] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][739] Accuracy: total average 97.8, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  96.  94.  97.  98.
#   99.]
# [Train][749] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][749] Accuracy: total average 97.8, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  96.  94.  97.  98.
#   99.]
# [Test][749] Accuracy: total average 97.8, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  96.  94.  97.  98.
#   99.]
# [Train][759] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][759] Accuracy: total average 97.8, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  96.  94.  97.  98.
#   99.]
# [Train][769] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][769] Accuracy: total average 97.8, in each domain [100. 100. 100. 100. 100. 100.  99.  98.  95.  91.  96.  94.  97.  98.
#   99.]
# [Train][779] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][779] Accuracy: total average 97.7, in each domain [100. 100. 100. 100. 100. 100.  99.  97.  95.  91.  96.  94.  97.  98.
#   99.]
# [Train][789] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][789] Accuracy: total average 97.7, in each domain [100. 100. 100. 100. 100. 100.  99.  97.  95.  91.  96.  94.  97.  98.
#   99.]
# [Train][799] Loss: D 2.706 E_gan -2.706 E_pred 0.001
# [Train][799] Accuracy: total average 97.7, in each domain [100. 100. 100. 100. 100. 100.  99.  97.  95.  91.  96.  94.  97.  98.
#   99.]
# [Test][799] Accuracy: total average 97.7, in each domain [100. 100. 100. 100. 100. 100.  99.  97.  95.  91.  96.  94.  97.  98.
#   99.]

# %%
# visualize the model result
from plot import plot_data_and_label
info = read_pickle(opt.outf + '/pred.pkl')
fig, ax = plt.subplots(1, 1, figsize=(6, 6 * 0.9))
print(info['data'].shape)
info['data'] = info['data'] * data_std + data_mean
plot_data_and_label(ax, info['data'], info['label'])
plt.title(f"Model's prediction: {opt.model}", fontsize=20)
plt.show()
# Out:
# (1500, 2)
